# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import mysql.connector

# %%
f=cv2.imread('datasets/kiran.jpg')

# %%
#plt.imshow(f,cmap='gray')

# %%
#cv2.imshow('outputImage',f)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
print(f.shape)
# Out:
# (4032, 3024, 3)

# %%
img2=cv2.cvtColor(f,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img2)

# %%
face_cascade = cv2.CascadeClassifier('datasets/haarcascades/haarcascade_frontalface_default.xml')
path='dataset'

# %%
def getProfile():
   # conn=sqlite3.connect('FaceBase.db')
    #cmd="SELECT* FROM People WHERE ID="+str(id)
   # cursor=conn.execute(cmd)
    conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root"
)

    cursor = conn.cursor()
    cursor.execute("INSERT INTO kiran.Camera (img) VALUES(%s)",(frame,))
    profile=None
    for row in cursor:
        profile=row
    conn.close()
    return profile

# %%
cap=cv2.VideoCapture(0)
font = cv2.FONT_HERSHEY_SIMPLEX

def face_extractor(img):
    faces = face_cascade.detectMultiScale(img, 1.3, 5)
    if faces is ():
        return None
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        cropped_face = img[y:y+h, x:x+w]
    return cropped_face
while True:
    _, frame = cap.read()
     
        #name="None matching"
       # name='kiran'
       # profile=getProfile()
      #  if(profile!=None):
       #     cv2.putText(frame, (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        

 #   else:
  #      cv2.putText(frame,"No face found", (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
cv2.imshow('Video', frame)
if cv2.waitKey(1) & 0xFF == ord('q'):
     break
cap.release()
cv2.destroyAllWindows()
# Out:
# <>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-11-8ffcc4af5a8d>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\conversion.py in to_mysql(self, value)
#     182         try:
# --> 183             return getattr(self, "_{0}_to_mysql".format(type_name))(value)
#     184         except AttributeError:
#
# AttributeError: 'MySQLConverter' object has no attribute '_ndarray_to_mysql'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\cursor.py in _process_params(self, params)
#     431
# --> 432             res = [to_mysql(i) for i in res]
#     433             res = [escape(i) for i in res]
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor.py in <listcomp>(.0)
#     431
# --> 432             res = [to_mysql(i) for i in res]
# ...

# %%
  face=face_extractor(frame)
    if type(face) is np.ndarray:
        face = cv2.resize(face, (224, 224))
        im = Image.fromarray(face, 'RGB')
        img_array = np.array(im)
        img_array = np.expand_dims(img_array, axis=0)

# %%
import cv2
video = cv2.VideoCapture(0)
faceCascade = cv2.CascadeClassifier("datasets/haarcascades/haarcascade_frontalface_default.xml")
smileCascade = cv2.CascadeClassifier("datasets/haarcascades/haarcascade_smile.xml")
while True:
    success,img = video.read()
    grayImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(grayImg,1.1,4)
    cnt=1
    keyPressed = cv2.waitKey(1)
    for x,y,w,h in faces:
        img = cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,0),3)
        smiles = smileCascade.detectMultiScale(grayImg,1.8,15)
        for x,y,w,h in faces:
            img = cv2.rectangle(img,(x,y),(x+w,y+h),(100,100,100),5)
            print("Image "+str(cnt)+"Saved")
            path=r'dataset/'+str(cnt)+'.jpg'
            cv2.imwrite(path,img)
            cnt +=1
            if(cnt>=2):    
                break
                
    cv2.imshow('live video',img)
    if(keyPressed & 0xFF==ord('q')):
        break
video.release()                                  
cv2.destroyAllWindows()

# %%
capp = cv2.VideoCapture(0)
ret,frame=capp.read()
ret,frame1=capp.read()

#faceCascade = cv2.CascadeClassifier("datasets/haarcascades/haarcascade_frontalface_default.xml")
while capp.isOpened():
    diff=cv2.absdiff(frame,frame1)
    grey=cv2.cvtColor(diff,cv2.COLOR_BGR2GRAY)
    cv2.imshow("live video",frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
capp.release()                                  
cv2.destroyAllWindows()

# %%
Im_pil=Image.open('datasets/kiran.jpg').convert('L')

# %%
Im_pil.show()

# %%
kernel=np.ones((5,5),np.uint8)

# %%
imgblur=cv2.GaussianBlur(img2,(7,7),0)

# %%
imgcanny=cv2.Canny(imgblur,100,200)

# %%
img_dilat=cv2.dilate(img2,kernel,iterations=1)

# %%
cv2.imshow("img dilat",img_dilat)

# %%
import cv2
import mysql.connector

try:
    conn = mysql.connector.connect(host = "localhost", user = "root",passwd = "root", database = "kiran")  
except:
        print(err)
cursor = conn.cursor()
cap = cv2.VideoCapture(0)

frame = cap.read()

cursor.execute("INSERT INTO camera (img)VALUES (%s)",(frame))
conn.commit()
cap.release()
if cv2.waitKey(1) & 0xFF == ord('q'):
     break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\conversion.py in to_mysql(self, value)
#     182         try:
# --> 183             return getattr(self, "_{0}_to_mysql".format(type_name))(value)
#     184         except AttributeError:
#
# AttributeError: 'MySQLConverter' object has no attribute '_ndarray_to_mysql'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\cursor.py in _process_params(self, params)
#     431
# --> 432             res = [to_mysql(i) for i in res]
#     433             res = [escape(i) for i in res]
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor.py in <listcomp>(.0)
#     431
# --> 432             res = [to_mysql(i) for i in res]
# ...

# %%
import cv2, sys, numpy, os 
size = 4
haar_file = 'haarcascade_frontalface_default.xml'
datasets = 'datasets'
  
# Part 1: Create fisherRecognizer 
print('Recognizing Face Please Be in sufficient Lights...') 
  
# Create a list of images and a list of corresponding names 
(images, lables, names, id) = ([], [], {}, 0) 
for (subdirs, dirs, files) in os.walk(datasets): 
    for subdir in dirs: 
        names[id] = subdir 
        subjectpath = os.path.join(datasets, subdir) 
        for filename in os.listdir(subjectpath): 
            path = subjectpath + '/' + filename 
            lable = id
            images.append(cv2.imread(path, 0)) 
            lables.append(int(lable)) 
        id += 1
(width, height) = (130, 100) 
  
# Create a Numpy array from the two lists above 
(images, lables) = [numpy.array(lis) for lis in [images, lables]] 
  
# OpenCV trains a model from the images 
# NOTE FOR OpenCV2: remove '.face' 
model = cv2.LBPHFaceRecognizer_create() 
model.train(images, lables) 
  
# Part 2: Use fisherRecognizer on camera stream 
face_cascade = cv2.CascadeClassifier(haar_file) 
webcam = cv2.VideoCapture(0) 
while True: 
    (_, im) = webcam.read() 
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY) 
    faces = face_cascade.detectMultiScale(gray, 1.3, 5) 
    for (x, y, w, h) in faces: 
        cv2.rectangle(im, (x, y), (x + w, y + h), (255, 0, 0), 2) 
        face = gray[y:y + h, x:x + w] 
        face_resize = cv2.resize(face, (width, height)) 
        # Try to recognize the face 
        prediction = model.predict(face_resize) 
        cv2.rectangle(im, (x, y), (x + w, y + h), (0, 255, 0), 3) 
  
        if prediction[1]<500: 
  
           cv2.putText(im, '% s - %.0f' % 
(names[prediction[0]], prediction[1]), (x-10, y-10),  
cv2.FONT_HERSHEY_PLAIN, 1, (0, 255, 0)) 
        else: 
          cv2.putText(im, 'not recognized',  
(x-10, y-10), cv2.FONT_HERSHEY_PLAIN, 1, (0, 255, 0)) 
  
    cv2.imshow('OpenCV', im) 
      
    key = cv2.waitKey(10) 
    if key == 27: 
        break
# Out:
# Recognizing Face Please Be in sufficient Lights...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-ebef13aa246a> in <module>
#      26 # OpenCV trains a model from the images
#      27 # NOTE FOR OpenCV2: remove '.face'
# ---> 28 model = cv2.LBPHFaceRecognizer_create()
#      29 model.train(images, lables)
#      30
#
# AttributeError: module 'cv2.cv2' has no attribute 'LBPHFaceRecognizer_create'
